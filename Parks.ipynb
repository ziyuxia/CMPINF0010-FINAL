# %%
#Jin Chul Cha, jcc147


import numpy as np
import pandas as pd
spots = pd.read_csv("parks.csv", index_col=0)
#spots["neighborhood"].value_counts().sum().sort_values(ascending=False)
spots["neighborhood"].value_counts().head(20)

q = spots["type"] == "Park"
parks = spots[q]
parks["neighborhood"].value_counts().head(20)
# Out:
# Beechview                6
# South Side Slopes        6
# Troy Hill                5
# Hazelwood                5
# Mount Washington         5
# Elliott                  4
# Sheraden                 4
# Marshall-Shadeland       4
# East Liberty             4
# Brighton Heights         3
# Spring Hill-City View    3
# Squirrel Hill South      3
# Bloomfield               3
# Garfield                 3
# North Shore              3
# Crawford-Roberts         3
# South Oakland            3
# Carrick                  3
# Upper Lawrenceville      3
# Manchester               3
# Name: neighborhood, dtype: int64

# %%
q = spots["type"] == "Park"
parkSpots = spots[q]
parkSpots["neighborhood"].value_counts().head(20).plot(kind='bar')

# %% [markdown]
# The dataset for the parks and public spaces in Pittsburgh (City of Pittsburgh Parks, https://data.wprdc.org/dataset/parks) showed that all neighborhoods have at least three parks in their vincinity. Access to parks is not an issue to any neighborhood, but the neighborhood with the most park is Beachview and South Side Slopes. The bar chart graph was shorten to 20 neighborhoods for better visualization (all neighborhoods have at least three parks, regardless of not showing up in the bar chart).
